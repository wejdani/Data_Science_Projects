# %% [markdown]
# <img align="right" width="200" height="200" src="https://static.wikia.nocookie.net/lego/images/2/23/PPG_logo.png">
#
# # <span style="color:#EF7C8E">Weekend Project - GPU EDA - Python </span>
#
#
#
# ## <span style="color:#55BB99"> Group: Power Puff Girls</span>
# ### <span style="color:#726060"> Members: Wejdan Al-Ahmadi - Sara Aldubaie</span>
# <hr style="border:2px solid gray"> </hr>

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 

import plotly.express as px
import plotly.graph_objects as go
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objects as go
import random
import dash
import json
from dash.dependencies import Input, Output
from dash.exceptions import PreventUpdate
#import dash_bootstrap_components as dbc
from datetime import datetime

# %%
# reading the file 
gpu = pd.read_csv('./data/All_GPUs.csv')

# %%
# view all columns in the dataset 
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(gpu.head(30))
# Out:
#                   Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                  Tesla G92b              NaN         NaN    738 MHz
# 1                     R600 XT       1366 x 768         NaN       \n-
# 2                    R600 PRO       1366 x 768         NaN       \n-
# 3                       RV630       1024 x 768         NaN       \n-
# 4                       RV630       1024 x 768         NaN       \n-
# 5                       RV630       1024 x 768         NaN       \n-
# 6               R700 RV790 XT      1920 x 1080         NaN    870 MHz
# 7                     R600 GT       1024 x 768         NaN       \n-
# 8              Pitcairn XT GL      1920 x 1080         NaN       \n-
# 9                       RV100              NaN         NaN       \n-
# 10                  NV28GL A2              NaN         NaN       \n-
# 11                Fermi GF110      1920 x 1080         NaN    650 MHz
# 12               Kepler GK110              NaN         NaN    705 MHz
# 13               Kepler GK110      2560 x 1600         NaN    706 MHz
# 14                      RV200              NaN         NaN       \n-
# 15  GCN 1.1 Oland XT + Kaveri       1600 x 900   1100 MHz    1050 MHz
# 16            Kepler GK104 x2              NaN         NaN       \n-
# 17               Kepler GK110              NaN         NaN    732 MHz
# 18              Skylake GT3-E       1366 x 768   1000 MHz     300 MHz
# 19                       R360       1024 x 768         NaN       \n-
# 20                Fermi GF100              NaN         NaN    575 MHz
# 21                Fermi GF100              NaN         NaN    575 MHz
# 22                    NV25 A2              NaN         NaN       \n-
# 23                  NV28GL A2              NaN         NaN       \n-
# 24              Skylake GT3-E       1366 x 768   1000 MHz     300 MHz
# 25                       NV28              NaN         NaN       \n-
# 26                Fermi GF100              NaN         NaN    575 MHz
# 27              Skylake GT3-E       1366 x 768   1050 MHz     300 MHz
# 28              Skylake GT3-E       1366 x 768    950 MHz     300 MHz
# 29                Haswell GT3       1366 x 768   1100 MHz     200 MHz
#
#     DVI_Connection Dedicated Direct_X  DisplayPort_Connection  \
# 0              2.0       Yes  DX 10.0                     NaN
# 1              2.0       Yes    DX 10                     NaN
# 2              2.0       Yes    DX 10                     NaN
# 3              2.0       Yes    DX 10                     NaN
# 4              2.0       Yes    DX 10                     NaN
# 5              2.0       Yes    DX 10                     NaN
# 6              1.0       Yes  DX 10.1                     NaN
# 7              2.0       Yes    DX 10                     NaN
# 8              0.0       Yes  DX 11.2                     NaN
# 9              NaN       Yes     DX 7                     NaN
# 10             2.0       Yes   DX 8.1                     NaN
# 11             2.0       Yes  DX 12.0                     0.0
# 12             0.0       Yes  DX 12.0                     NaN
# 13             0.0       Yes  DX 12.0                     NaN
# 14             NaN       Yes     DX 7                     NaN
# 15             1.0       Yes  DX 12.0                     0.0
# 16             0.0       Yes  DX 11.1                     NaN
# 17             0.0       Yes  DX 12.0                     NaN
# 18             NaN        No  DX 12.1                     NaN
# 19             1.0       Yes     DX 9                     0.0
# 20             1.0       Yes  DX 12.0                     NaN
# 21             1.0       Yes  DX 12.0                     NaN
# 22             2.0       Yes   DX 8.1                     NaN
# 23             2.0       Yes   DX 8.1                     NaN
# 24             NaN        No  DX 12.1                     NaN
# 25             2.0       Yes   DX 8.1                     NaN
# 26             1.0       Yes  DX 12.0                     NaN
# 27             NaN        No  DX 12.1                     NaN
# 28             NaN        No  DX 12.1                     NaN
# 29             NaN        No  DX 11.1                     NaN
#
#     HDMI_Connection Integrated    L2_Cache Manufacturer  Max_Power     Memory  \
# 0               0.0         No         0KB       Nvidia  141 Watts   1024 MB
# 1               0.0         No         0KB          AMD  215 Watts    512 MB
# 2               0.0         No         0KB          AMD  200 Watts    512 MB
# 3               0.0         No         0KB          AMD        NaN    256 MB
# 4               0.0         No         0KB          AMD   45 Watts    256 MB
# 5               0.0         No         0KB          AMD   50 Watts    256 MB
# 6               1.0         No         0KB          AMD  190 Watts   2048 MB
# 7               0.0         No         0KB          AMD  150 Watts    256 MB
# 8               0.0         No         0KB          AMD  150 Watts   2048 MB
# 9               NaN         No         0KB          AMD   32 Watts     64 MB
# 10              0.0         No         0KB       Nvidia        NaN    128 MB
# 11              1.0         No       768KB       Nvidia  250 Watts   6144 MB
# 12              0.0         No      1536KB       Nvidia  225 Watts   5120 MB
# 13              0.0         No      1536KB       Nvidia  245 Watts  12288 MB
# 14              NaN         No         0KB          AMD        NaN     64 MB
# 15              1.0         No  2304KB(x2)          AMD  150 Watts   3072 MB
# 16              0.0         No         0KB       Nvidia  300 Watts   8192 MB
# 17              0.0         No      1536KB       Nvidia  235 Watts   6144 MB
# 18              NaN        Yes       512KB        Intel   28 Watts        NaN
# 19              0.0         No         0KB          AMD   60 Watts    256 MB
# 20              0.0         No       768KB       Nvidia  238 Watts   6144 MB
# 21              0.0         No       768KB       Nvidia  247 Watts   6144 MB
# 22              0.0         No         0KB       Nvidia        NaN    128 MB
# 23              0.0         No         0KB       Nvidia        NaN    128 MB
# 24              NaN        Yes       512KB        Intel   15 Watts        NaN
# 25              0.0         No         0KB       Nvidia        NaN    128 MB
# 26              0.0         No       768KB       Nvidia  238 Watts   3072 MB
# 27              NaN        Yes       512KB        Intel   28 Watts        NaN
# 28              NaN        Yes       512KB        Intel   15 Watts        NaN
# 29              NaN        Yes       512KB        Intel   15 Watts        NaN
#
#    Memory_Bandwidth Memory_Bus Memory_Speed Memory_Type  \
# 0          64GB/sec   256 Bit      1000 MHz       GDDR3
# 1         106GB/sec   512 Bit       828 MHz       GDDR3
# 2        51.2GB/sec   256 Bit       800 MHz       GDDR3
# 3        36.8GB/sec   128 Bit      1150 MHz       GDDR4
# 4        22.4GB/sec   128 Bit       700 MHz       GDDR3
# 5        35.2GB/sec   128 Bit      1100 MHz       GDDR4
# 6       134.4GB/sec   256 Bit      1050 MHz       GDDR5
# 7        51.2GB/sec   256 Bit       800 MHz       GDDR3
# 8         160GB/sec   256 Bit      1250 MHz       GDDR5
# 9         2.9GB/sec    64 Bit       366 MHz         DDR
# 10        5.2GB/sec   128 Bit       325 MHz         DDR
# 11      177.6GB/sec   384 Bit       925 MHz       GDDR5
# 12        168GB/sec   320 Bit      1050 MHz       GDDR5
# 13      288.4GB/sec   384 Bit      1502 MHz       GDDR5
# 14        5.8GB/sec   128 Bit       360 MHz         DDR
# 15       57.6GB/sec   128 Bit       900 MHz        DDR3
# 16        320GB/sec   512 Bit      1250 MHz       GDDR5
# 17      249.6GB/sec   384 Bit      1300 MHz       GDDR5
# 18       34.1GB/sec   128 Bit      1067 MHz        DDR4
# 19       23.4GB/sec   256 Bit       730 MHz         DDR
# 20        144GB/sec   384 Bit       750 MHz       GDDR5
# 21        144GB/sec   384 Bit       750 MHz       GDDR5
# 22        3.6GB/sec   128 Bit       225 MHz         DDR
# 23        5.2GB/sec   128 Bit       325 MHz         DDR
# 24       34.1GB/sec   128 Bit      1067 MHz        DDR4
# 25        4.4GB/sec   128 Bit       275 MHz         DDR
# 26        144GB/sec   384 Bit       750 MHz       GDDR5
# 27       34.1GB/sec   128 Bit      1067 MHz        DDR4
# 28       34.1GB/sec   128 Bit      1067 MHz        DDR4
# 29       25.6GB/sec   128 Bit       800 MHz        DDR3
#
#                                                  Name Notebook_GPU  Open_GL  \
# 0                                     GeForce GTS 150           No      3.3
# 1                             Radeon HD 2900 XT 512MB           No      3.1
# 2                                  Radeon HD 2900 Pro           No      3.1
# 3                   Radeon HD 2600 XT Diamond Edition           No      3.3
# 4                                   Radeon HD 2600 XT           No      3.1
# 5                       Radeon HD 2600 XT 256MB GDDR4           No      3.3
# 6      Radeon HD 4890 Sapphire Vapor-X OC 2GB Edition           No      3.3
# 7                                   Radeon HD 2900 GT           No      3.1
# 8                                        FirePro D300           No      4.3
# 9                                    Radeon 7000 64mb           No      1.4
# 10                                    Quadro4 980 XGL           No      1.5
# 11                                        Tesla M2090           No      4.5
# 12                                          Tesla K20           No      4.5
# 13                                         Tesla K40c           No      4.5
# 14                          All-in-Wonder Radeon 7500           No      1.4
# 15  Radeon R7 250 v2 MSI OC 2GB + Radeon R7 7870K ...           No      4.4
# 16                                          Tesla K10           No      4.2
# 17                                         Tesla K20X           No      4.5
# 18                                      Iris i3 6167U          Yes      4.4
# 19                                     Radeon 9800 XT           No      2.0
# 20                                        Tesla C2070           No      4.5
# 21                                        Tesla C2075           No      4.5
# 22                                    Quadro4 750 XGL           No      1.5
# 23                                    Quadro4 900 XGL           No      1.5
# 24                                      Iris i5 6360U          Yes      4.4
# 25                                    Quadro4 780 XGL           No      1.5
# 26                                        Tesla C2050           No      4.5
# 27                                      Iris i5 6267U          Yes      4.4
# 28                                      Iris i5 6260U          Yes      4.4
# 29                                      Iris i5 4258U          Yes      4.0
#
#                    PSU   Pixel_Rate       Power_Connector Process    ROPs  \
# 0   450 Watt & 38 Amps  12 GPixel/s                 None     55nm      16
# 1   550 Watt & 35 Amps  12 GPixel/s                 None     80nm      16
# 2   550 Watt & 35 Amps  10 GPixel/s                 None     80nm      16
# 3                  NaN   3 GPixel/s                 None     65nm       4
# 4   400 Watt & 25 Amps   3 GPixel/s                 None     65nm       4
# 5   400 Watt & 26 Amps   3 GPixel/s                 None     65nm       4
# 6   500 Watt & 37 Amps  14 GPixel/s             2x 6-pin     55nm      16
# 7   550 Watt & 30 Amps   7 GPixel/s                 None     80nm      12
# 8   500 Watt & 20 Amps  25 GPixel/s                 None     28nm      32
# 9                  NaN          NaN                 None      NaN     NaN
# 10                 NaN   1 GPixel/s                 None    150nm       4
# 11  600 Watt & 42 Amps  31 GPixel/s  1x 6-pin + 1x 8-pin     40nm      48
# 12            650 Watt          NaN                 None     28nm     NaN
# 13                 NaN  34 GPixel/s                 None     28nm      48
# 14                 NaN          NaN                 None      NaN     NaN
# 15  400 Watt & 27 Amps  18 GPixel/s                 None     28nm  8 (x2)
# 16            650 Watt          NaN                 None     28nm     NaN
# 17                 NaN          NaN                 None     28nm     NaN
# 18                 NaN   2 GPixel/s                   NaN    14nm       2
# 19  400 Watt & 20 Amps   3 GPixel/s                 None    150nm       8
# 20            750 Watt          NaN                 None     40nm     NaN
# 21            750 Watt          NaN                 None     40nm     NaN
# 22                 NaN   1 GPixel/s                 None    150nm       4
# 23                 NaN   1 GPixel/s                 None    150nm       4
# 24                 NaN   2 GPixel/s                   NaN    14nm       2
# 25                 NaN   1 GPixel/s             1x 6-pin    150nm       4
# 26            750 Watt          NaN                 None     40nm     NaN
# 27                 NaN   2 GPixel/s                   NaN    14nm       2
# 28                 NaN   2 GPixel/s                   NaN    14nm       2
# 29                 NaN   4 GPixel/s                   NaN    22nm       4
#
#       Release_Date Release_Price Resolution_WxH SLI_Crossfire  Shader   TMUs  \
# 0   \n01-Mar-2009            NaN      2560x1600           Yes     4.0   64.0
# 1   \n14-May-2007            NaN      2560x1600           Yes     4.0   16.0
# 2   \n07-Dec-2007            NaN      2560x1600           Yes     4.0   16.0
# 3   \n01-Jul-2007            NaN      2560x1600           Yes     4.0    8.0
# 4   \n28-Jun-2007            NaN      2560x1600           Yes     4.0    8.0
# 5   \n26-Jun-2007            NaN      2560x1600           Yes     4.0    8.0
# 6   \n13-Jul-2009            NaN      2560x1600           Yes     4.1   40.0
# 7   \n06-Nov-2007            NaN      2560x1600           Yes     4.0   12.0
# 8   \n18-Jan-2014            NaN      4096x2160           Yes     5.0   80.0
# 9   \n02-Jan-2001            NaN      1600x1200            No     1.0    NaN
# 10  \n01-Nov-2002            NaN            NaN            No     1.3    8.0
# 11  \n25-Jul-2011            NaN      2560x1600           Yes     5.0   56.0
# 12  \n01-Nov-2012            NaN      4096x2160            No     5.0    NaN
# 13  \n12-Nov-2013            NaN      4096x2160           Yes     5.0  240.0
# 14  \n22-Jan-2002            NaN      1600x1200            No     NaN    NaN
# 15  \n28-May-2015            NaN      2560x1600           Yes     5.0   28.0
# 16  \n15-May-2012            NaN      4096x2160            No     5.0    NaN
# 17  \n12-Nov-2012            NaN      4096x2160           Yes     5.0    NaN
# 18  \n01-Sep-2015            NaN      4096x2304            No     5.0    8.0
# 19  \n01-Oct-2003            NaN      2048x1536            No     2.0    8.0
# 20  \n01-Sep-2010            NaN      2560x1600            No     5.0    NaN
# 21  \n01-Jul-2011            NaN      2560x1600            No     5.0    NaN
# 22  \n19-Feb-2002            NaN            NaN            No     1.3    8.0
# 23  \n01-Nov-2002            NaN            NaN            No     1.3    8.0
# 24  \n01-Sep-2015            NaN      4096x2304            No     5.0    8.0
# 25  \n01-Nov-2002            NaN            NaN            No     1.3    8.0
# 26  \n01-May-2010            NaN      2560x1600            No     5.0    NaN
# 27  \n01-Sep-2015            NaN      4096x2304            No     5.0    8.0
# 28  \n01-Sep-2015            NaN      4096x2304            No     5.0    8.0
# 29  \n02-Jun-2013            NaN      2560x1600            No     5.0    8.0
#
#     Texture_Rate  VGA_Connection
# 0    47 GTexel/s             0.0
# 1    12 GTexel/s             0.0
# 2    10 GTexel/s             0.0
# 3     7 GTexel/s             0.0
# 4     6 GTexel/s             0.0
# 5     6 GTexel/s             0.0
# 6    35 GTexel/s             1.0
# 7     7 GTexel/s             0.0
# 8    62 GTexel/s             0.0
# 9            NaN             NaN
# 10    2 GTexel/s             0.0
# 11   36 GTexel/s             0.0
# 12           NaN             0.0
# 13  169 GTexel/s             0.0
# 14           NaN             1.0
# 15   62 GTexel/s             1.0
# 16           NaN             0.0
# 17           NaN             0.0
# 18    8 GTexel/s             NaN
# 19    3 GTexel/s             1.0
# 20           NaN             0.0
# 21           NaN             0.0
# 22    2 GTexel/s             0.0
# 23    2 GTexel/s             0.0
# 24    8 GTexel/s             NaN
# 25    2 GTexel/s             0.0
# 26           NaN             0.0
# 27    8 GTexel/s             NaN
# 28    8 GTexel/s             NaN
# 29    9 GTexel/s             NaN

# %%
# number of rows and columns 
gpu.shape
# Out:
# (3406, 34)

# %%
# number of null values in each column 
gpu.isnull().sum()
# Out:
# Architecture                62
# Best_Resolution            642
# Boost_Clock               1960
# Core_Speed                   0
# DVI_Connection             750
# Dedicated                   14
# Direct_X                     6
# DisplayPort_Connection    2549
# HDMI_Connection            763
# Integrated                  14
# L2_Cache                     0
# Manufacturer                 0
# Max_Power                  625
# Memory                     420
# Memory_Bandwidth           121
# Memory_Bus                  62
# Memory_Speed               105
# Memory_Type                 56
# Name                         0
# Notebook_GPU                 0
# Open_GL                     40
# PSU                       1175
# Pixel_Rate                 544
# Power_Connector            709
# Process                    463
# ROPs                       538
# Release_Date                 0
# Release_Price             2850
# Resolution_WxH             195
# SLI_Crossfire                0
# Shader                     107
# TMUs                       538
# Texture_Rate               544
# VGA_Connection             758
# dtype: int64

# %% [markdown]
# Nulls Pandas can recognize:
# * NaN HDMI DisplayPort connection
# * Best Resolution has NaNs
# * Boost Clock has NaNs
# * DVI connection has NaNs
# Nulls Found that pandas cannot detect:
# * '\n-' in Core_Speed column
# * None in Power COnnector (check and replace None for the entire dataset with NaN)
# * remove \n from date column

# %%
gpu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3406 entries, 0 to 3405
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Architecture            3344 non-null   object
#  1   Best_Resolution         2764 non-null   object
#  2   Boost_Clock             1446 non-null   object
#  3   Core_Speed              3406 non-null   object
#  4   DVI_Connection          2656 non-null   float64
#  5   Dedicated               3392 non-null   object
#  6   Direct_X                3400 non-null   object
#  7   DisplayPort_Connection  857 non-null    float64
#  8   HDMI_Connection         2643 non-null   float64
#  9   Integrated              3392 non-null   object
#  10  L2_Cache                3406 non-null   object
#  11  Manufacturer            3406 non-null   object
#  12  Max_Power               2781 non-null   object
#  13  Memory                  2986 non-null   object
#  14  Memory_Bandwidth        3285 non-null   object
#  15  Memory_Bus              3344 non-null   object
#  16  Memory_Speed            3301 non-null   object
#  17  Memory_Type             3350 non-null   object
#  18  Name                    3406 non-null   object
#  19  Notebook_GPU            3406 non-null   object
#  20  Open_GL                 3366 non-null   float64
#  21  PSU                     2231 non-null   object
#  22  Pixel_Rate              2862 non-null   object
#  23  Power_Connector         2697 non-null   object
#  24  Process                 2943 non-null   object
#  25  ROPs                    2868 non-null   object
#  26  Release_Date            3406 non-null   object
#  27  Release_Price           556 non-null    object
#  28  Resolution_WxH          3211 non-null   object
#  29  SLI_Crossfire           3406 non-null   object
#  30  Shader                  3299 non-null   float64
#  31  TMUs                    2868 non-null   float64
#  32  Texture_Rate            2862 non-null   object
#  33  VGA_Connection          2648 non-null   float64
# dtypes: float64(7), object(27)
# memory usage: 904.8+ KB

# %% [markdown]
# - replace NaN with 0 - Sara <span style="color:#55BB99">**DONE**</span>
# - replace NaN with No - Wejdan <span style="color:#55BB99">**DONE**</span>
# - replace NaN with mode - Wejdan <span style="color:#55BB99">**DONE**</span>
# - replace NaN with ffill - Sara <span style="color:#55BB99">**DONE**</span>
# - Date - Wejdan <span style="color:#55BB99">**DONE**</span>
# - Price - Sara <span style="color:#55BB99">DONE but can be changed</span>

# %% [markdown]
# Column Metadata:
# * Architecture: <span style="color:#55BB99">**DONE**</span>
#
# The GPU architecture used on the graphics card. (drop rows with null: 62 rows)
# * Best_Resolution: <span style="color:#55BB99">**DONE**</span>
#
# The best Screensize for reducing bottleneck to a minimum. (replace with mode: 642 rows)
# * Boost_Clock: <span style="color:#55BB99">**DONE**</span>
#
# the MHz speed of the graphics card (ffill method, 1960 rows)
# * Core_Speed: <span style="color:#55BB99">**DONE**</span>
#
# the speed of the graphics card (NaN in form pandas cant read: "\n" and "\n-" , 936 rows, replace those with NaN and do ffill)
# * DVI_Connection: <span style="color:#55BB99">**DONE**</span>
#
# How many DVI connections does the graphics card have (replace NaN with 0, 750 rows)
# * Dedicated: <span style="color:#55BB99">**DONE**</span>
#
# Is the graphics card dedicated (replace NaN with "No", 14 rows)
# * Direct_X: <span style="color:#55BB99">**DONE**</span>
#
# What Direct X can the graphics card support (replace NaN with mode, 6 rows)
# * DisplayPort_Connection: <span style="color:#55BB99">**DONE**</span>
#
# How many DisplayPort connections does the graphics card have (replace NaN with 0, 2549 rows)
# * HDMI_Connection: <span style="color:#55BB99">**DONE**</span>
#
# How many HDMI connections does the graphics card have (replace NaN with 0, 763 rows)
# * Integrated: <span style="color:#55BB99">**DONE**</span>
#
# Is the graphics card integrated (replace NaN with "No", 14 rows)
# * L2_Cache:
#
# The L2 Cache of graphics card
# * Manufacturer:
#
# GPU manufacturer.
# * Max_Power: <span style="color:#55BB99">**DONE**</span>
#
# What power in watts is required to run the graphics card
# * Memory: <span style="color:#55BB99">**DONE**</span>
#
# The memory of graphics card (replace with mode: 420 rows)
# * Memory_Bandwidth: <span style="color:#55BB99">**DONE**</span>
#
# The memory bandwidth (ffill method, 121 rows)
# * Memory_Bus: <span style="color:#55BB99">**DONE**</span>
#
# The memory bus of graphics card (replace with mode or ffill: 62 rows)
# * Memory_Speed: <span style="color:#55BB99">**DONE**</span>
#
# The memory speed of the graphic card's RAM(ffill method, 105 rows)
# * Memory_Type: <span style="color:#55BB99">**DONE**</span>
#
# The memory type of the graphics card(replace with mode: 56 rows)
# * Name:  <span style="color:#55BB99">**DONE**</span>
#
# Name of the GPU. (divide first part as line, second specs/line-specifications)
#
# * Notebook_GPU:
#
# Is it for Notebooks or Desktop.
#
# * Open_GL:
#
# What Open GL can the graphics card support.(replace with mode: 40 rows)
#
# * PSU: <span style="color:#55BB99">**DONE**</span>
#
# What Power Supply is needed to run the graphics card.(replace with ffill: 1175 rows)
#
# * Pixel_Rate:<span style="color:#55BB99">**DONE**</span>
#
# The number of pixels per second the GPU can produce.(replace with ffill/mode: 544 rows)
#
# * Power_Connector:  <span style="color:#55BB99">**DONE**</span>
#
# Power Connector is needed to run the graphics card(convert none to null and ffill 2,363 rows)
#
# * Process: <span style="color:#55BB99">**DONE**</span>
#
# What nm technology does the GPU use. (replace with ffill: 463 rows)
#
# * ROPs: <span style="color:#55BB99">**DONE**</span>
#
# How many Raster Operation Pipelines does the GPU have (replace NaN with 0, 538 rows)
#
# * Release_Date: <span style="color:#55BB99">**DONE**</span>
#
# The GPU release date. (remove "\n" and "\n " and "\t" from the end, and "\nUnknown" to NaN and then replace with ffill and then convert to date format)
#
# * Release_Price: <span style="color:#55BB99">**DONE**</span>
#
# The GPU price at time of release. (remove the $, sub categorize it based on a metric/column and then fill the price with the mode of that metric/column *last step because its based on other columns)
#
# * Resolution_WxH: <span style="color:#55BB99">**DONE**</span>
# Maximum supported resolution. (replace with mode: 195 rows)
#
# * SLI_Crossfire:
#
# Does the GPU support SLI or Crossfire Technology.
# * Shader: <span style="color:#55BB99">**DONE**</span>
#
# What Shader Model can the graphics card support.(replace NaN with 0, 107 rows)
#
# * TMUs:  <span style="color:#55BB99">**DONE**</span>
#
# How many texture mapping units does the GPU have.(replace NaN with 0, 538 rows)
#
# * Texture_Rate: <span style="color:#55BB99">**DONE**</span>
#
# How many texture pixels per second can the GPU produce.(replace NaN with ffill, 544 rows)
#
# * VGA_Connection: <span style="color:#55BB99">**DONE**</span>
#
# How many VGA connections does GPU have.(replace NaN with 0, 758 rows)

# %% [markdown]
# ## <span style="color:#EF7C8E">Data cleaning<span style="color:#55BB99">(Sara):</span>

# %%
#---------------------------------- drop rows ----------------------------------#

# drop the rows with empty value in column (Architecture) 
gpu.dropna(axis = 'index', how = 'all', subset = ['Architecture'], inplace = True)

# %%
#---------------------------------- Replace NaN values with zero ----------------------------------#

# list with all columns needed to replace Null value to zero 
to_zero = ['DVI_Connection', 'DisplayPort_Connection', 'HDMI_Connection','ROPs', 'Shader', 'TMUs', 'VGA_Connection']
# replace null value with zero 
gpu.update(gpu[to_zero].fillna(0))

# %%
#---------------------------------- Replace values to null ----------------------------------#

# list with values needed to be replaced
none_val = ['None ', 'None  ']
# replace 'None ' and 'None  ' values with null  
gpu['Power_Connector'] = gpu['Power_Connector'].replace(none_val, np.NaN)

# %%
#---------------------------------- filling null values using forward filling -----------------------------------#

# list with all columns needed to fill null using forward filling method
ffill_col = ['Texture_Rate', 'Process', 'Pixel_Rate', 'PSU', 'Memory_Speed', 'Memory_Bus', 'Memory_Bandwidth', 'Power_Connector', 'Boost_Clock']

# fill null value using forward filling method
gpu.update(gpu[ffill_col].fillna(method="ffill"))

# %%
#---------------------------------- filling null values using mode -----------------------------------#
# finding mode value 
Power_Connector_mode = gpu['Power_Connector'].mode()
Boost_Clock_mode = gpu['Boost_Clock'].mode()

# fill null value using forward filling method
gpu['Power_Connector'] = gpu['Power_Connector'].fillna(Power_Connector_mode)
gpu['Boost_Clock'] = gpu['Boost_Clock'].fillna(Boost_Clock_mode)

# %%
#---------------------------------- filling null values using backward filling -----------------------------------#
# list with all columns needed to fill null using backward filling method
bfill_col = ['Power_Connector', 'Boost_Clock']

# fill null value using forward filling method
gpu.update(gpu[bfill_col].fillna(method="bfill"))

# %%
#---------------------------------- price column -----------------------------------#

# removing '$' from value and any other characters if exists
gpu['Release_Price'] = gpu['Release_Price'].replace({'\$':''}, regex = True)

# convert column type to float 
gpu['Release_Price'] = gpu['Release_Price'].astype(float)

# fill prices based on memory type 
gpu['Release_Price'] = gpu['Release_Price'].fillna(gpu.groupby('Memory_Type')['Release_Price'].transform('mean'))

# fill prices based on Core  Speed
gpu['Release_Price'] = gpu['Release_Price'].fillna(gpu.groupby('Core_Speed')['Release_Price'].transform('mean'))

# fill prices based on Shader
gpu['Release_Price'] = gpu['Release_Price'].fillna(gpu.groupby('Shader')['Release_Price'].transform('mean'))

# %% [markdown]
# ## <span style="color:#EF7C8E">Data cleaning<span style="color:#55BB99">(Wejdan):</span>

# %% [markdown]
# ### <span style="color:#EF7C8E">1. Replace NaN with Mode</span>
#
# * Best_Resolution:
# The best Screensize for reducing bottleneck to a minimum. (replace with mode: 642 rows) <span style="color:#55BB99">**DONE**</span>
# * Direct_X:
# What Direct X can the graphics card support (replace NaN with mode, 6 rows) <span style="color:#55BB99">**DONE**</span>
# * Memory:
# The memory of graphics card (replace with mode: 420 rows) <span style="color:#55BB99">**DONE**</span>
# * Memory_Bus:
# The memory bus of graphics card (replace with mode or ffill: 62 rows) <span style="color:#55BB99">**DONE**</span>
# * Memory_Type:
# The memory type of the graphics card(replace with mode: 56 rows) <span style="color:#55BB99">**DONE**</span>
# * Open_GL:
# What Open GL can the graphics card support.(replace with mode: 40 rows) <span style="color:#55BB99">**DONE**</span>
# * Resolution_WxH:
# Maximum supported resolution. (replace with mode: 195 rows) <span style="color:#55BB99">**DONE**</span>
#
# ### <span style="color:#EF7C8E">2. Replace NaN with "No"</span>
# * Integrated:
# Is the graphics card integrated (replace NaN with "No", 14 rows)  <span style="color:#55BB99">**DONE**</span>
# * Dedicated:
# Is the graphics card dedicated (replace NaN with "No", 14 rows) <span style="color:#55BB99">**DONE**</span>
#
# ### <span style="color:#EF7C8E">3. Date</span>
# * Release_Date:
# The GPU release date. (remove "\n" and "\n " and "\t" from the end, and "\nUnknown" to NaN and then replace with ffill and then convert to date format) <span style="color:#55BB99">**DONE**</span>
#
# ### <span style="color:#EF7C8E">4. General Cleanup</span>
# * Architecture:
# The GPU architecture used on the graphics card. (drop rows with null: 62 rows) <span style="color:#55BB99">**DONE**</span>
# * Name:
# Name of the GPU. (divide first part as line, second specs/line-specifications) <span style="color:#55BB99">**DONE**</span>

# %%
# REPLACE WITH NO:
# Replace all NaN with No because these columns have either a "Yes" or "No" Value
gpu.loc[:,['Dedicated','Integrated']]=gpu.loc[:,['Dedicated','Integrated']].fillna("No")

# %%
# REPLACE WITH MODE: 

# 1- Best_Resolution: 
gpu["Best_Resolution"].fillna(gpu["Best_Resolution"].mode()[0], inplace=True)
# 2- Direct_X
gpu["Direct_X"].fillna(gpu["Direct_X"].mode()[0], inplace=True)
# 3- Memory
gpu["Memory"].fillna(gpu["Memory"].mode()[0], inplace=True)
# 4- Memory_Bus
gpu["Memory_Bus"].fillna(gpu["Memory_Bus"].mode()[0], inplace=True)
# 5- Memory_Type
gpu["Memory_Type"].fillna(gpu["Memory_Type"].mode()[0], inplace=True)
# 6- Open_GL
gpu["Open_GL"].fillna(gpu["Open_GL"].mode()[0], inplace=True)
# 7- Resolution_WxH
gpu["Resolution_WxH"].fillna(gpu["Resolution_WxH"].mode()[0], inplace=True)
# 8- Max_Power
gpu["Max_Power"].fillna(method="ffill", inplace=True)

# %%
# GENERAL CLEANUP:
# Drop the 62 rows with missing Architecture 
gpu.dropna(subset=['Architecture'], how='all', inplace=True)

# Separate the Name into two new columns = Line and Line Description
gpu[["Line", "Line_Description"]] = gpu["Name"].str.split(" ", 1, expand=True)
# this resulted in one extra NaN so I dropped that row
gpu.dropna(subset=['Line_Description'], how='all', inplace=True)

# %%
# DATE CLEANUP 

# to remove "\n-", "\n" and "\t"
gpu['Release_Date']=gpu['Release_Date'].map(lambda x: x.lstrip('\n-').rstrip('\t'))

# to remove the white spaces
gpu['Release_Date']=gpu['Release_Date'].map(lambda x: x.strip())

# Replace all "Unknown Release Date" with NaN
gpu=gpu.replace({'Unknown Release Date':np.nan}) # there were 28 unknowns
# Drop the NaNs there was 28 so it wouldnt affect that much
gpu.dropna(subset=['Release_Date'], how='all', inplace=True)
# Convert to Datetime format
gpu['Release_Date']=gpu['Release_Date'].map(lambda x: datetime.strptime(x, '%d-%b-%Y'))

# %%
gpu.isnull().sum()
# Out:
# Architecture              0
# Best_Resolution           0
# Boost_Clock               0
# Core_Speed                0
# DVI_Connection            0
# Dedicated                 0
# Direct_X                  0
# DisplayPort_Connection    0
# HDMI_Connection           0
# Integrated                0
# L2_Cache                  0
# Manufacturer              0
# Max_Power                 0
# Memory                    0
# Memory_Bandwidth          0
# Memory_Bus                0
# Memory_Speed              0
# Memory_Type               0
# Name                      0
# Notebook_GPU              0
# Open_GL                   0
# PSU                       0
# Pixel_Rate                0
# Power_Connector           0
# Process                   0
# ROPs                      0
# Release_Date              0
# Release_Price             0
# Resolution_WxH            0
# SLI_Crossfire             0
# Shader                    0
# TMUs                      0
# Texture_Rate              0
# VGA_Connection            0
# Line                      0
# Line_Description          0
# dtype: int64
